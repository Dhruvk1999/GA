# %%
from data.fetch_data import *
from strategies.alphas import *
from utils.ga_utils import *
import warnings
from utils.optimizer import *
from utils.data_utils import * 

warnings.filterwarnings("ignore")
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
stock_data = fetch_stock_data("LT.NS",'2022-08-01','2023-08-08')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
def evaluate_strategy(data,alpha_func,*args):
    data["alpha"] = alpha_func(data,*args[:-2])
    data["alpha"] = normalize_alphas(data["alpha"])
    threshold = args[-2]
    stop_loss_percentage =args[-1]
    
    data = data.dropna()

    position = 0  # 0 for no position, 1 for long position
    profit = 0
    total_trades = 0
    winning_trades = 0
    stricly_winning_trades = 0
    allocated_funds = 100000
    no_of_shares = 0
    stop_loss_price = 0
    returns = []

    for i in range(1,len(data)):
        try:

            if position == 0:
                if data['alpha'][i] > threshold: 
                
                    position = 1  # Buy (enter long position)
                    entry_price = data['Close'][i]
                    stop_loss_price = entry_price - (entry_price * 0.01 * stop_loss_percentage)
                    # print(f"Entry: {entry_price} on {data.index[i]} Stop Loss: {stop_loss_price}")
                    total_trades += 1
                    no_of_shares = allocated_funds//entry_price
                    

                    
            elif position == 1 :
                
                if data['Close'][i] > entry_price:  # Adjust stop loss only when the price goes up
                    stop_loss_price = max(stop_loss_price, data['Close'][i] - (data['Close'][i] * 0.01 * stop_loss_percentage))
                    
                if data['Low'][i] < stop_loss_price:
                    position = 0  # Sell due to stop loss
                    exit_price = data['Open'][i] if stop_loss_price > data['Open'][i] else stop_loss_price
                    trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                    profit=trade_profit
                    allocated_funds += profit
                    no_of_shares =0
                    return_on_trade = (exit_price -entry_price) * 100/entry_price
                    returns.append(return_on_trade)
                    # print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
                    # print(f"Profit: {profit}")
                    
                    # mask = (results_data['Symbol'] == symbol) & (results_data['Exit_Date'].isnull())
                    # results_data.loc[mask, 'Exit_Date'] = data.index[i]
                    # results_data.loc[mask, 'Exit_Price'] = exit_price
           
                    if(exit_price>= entry_price):
                        winning_trades += 1
                    if(exit_price> entry_price):
                        stricly_winning_trades += 1
                # elif data['MACD_E'][i] < data['Signal_E'][i]:
                #     position = 0  # Sell due to exit condition
                #     exit_price = data['Close'][i]
                #     trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                #     profit=trade_profit#                     
                #     # print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
                #     # print(f"Profit: {profit}")

                #     allocated_funds += profit
                    
                    
                #     # mask = (results_data['Symbol'] == symbol) & (results_data['Exit_Date'].isnull())
                #     # results_data.loc[mask, 'Exit_Date'] = data.index[i]
                #     # results_data.loc[mask, 'Exit_Price'] = exit_price

                #     no_of_shares =0
                #     if(exit_price>= entry_price):
                #         winning_trades += 1
                #     if(exit_price> entry_price):
                #         stricly_winning_trades += 1
            
        except Exception as ex:
            print("Something caused the error",ex)
            break
        win_rate = winning_trades/total_trades if total_trades != 0 else 0

            # Calculate metrics
        metrics = {
            "Profit": profit,
            "Total Trades": total_trades,
            "Winning Trades": winning_trades,
            "Strictly Winning Trades": stricly_winning_trades,
            "Win Rate": win_rate,
            "Allocated Funds": allocated_funds,
            "Sharpe Ratio": calculate_sortino_ratio(pd.Series(returns))
        }

    return metrics

# %%
# run_ga_optimization(stock_data,generate_individual,alpha8,evaluate_strategy)

# %%
import importlib
tickers = []
alpha_function_names = ["alpha"+str(x) for x in range(1,2)]
alpha_functions = {}

for alpha_name in alpha_function_names:
    try:
        print(f"for {alpha_}")
        module = importlib.import_module("strategies.alphas")
        alpha_function = getattr(module, alpha_name)
        alpha_functions[alpha_name] = alpha_function

        best_metrics, best_individual = run_ga_optimization(stock_data, generate_individual, alpha_function, evaluate_strategy)

        results_dict["BPCL.NS"] = {
        "alpha_name": alpha_func.__name__,
        "best_metrics": best_metrics,
        "best_individual": best_individual
    }
        
    except AttributeError:
        print(f"Failed to import {alpha_name}")
# Out:
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
#
# Gen...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3727/3953931891.py in <module>
#      10         alpha_functions[alpha_name] = alpha_function
#      11
# ---> 12         best_metrics, best_individual = run_ga_optimization(stock_data, generate_individual, alpha_function, evaluate_strategy)
#      13
#      14         results_dict["BPCL.NS"] = {
#
# ~/GA/utils/optimizer.py in run_ga_optimization(stock_data, generate_individual, alpha_func, evaluate_strategy)
#      23
#      24     for generation in range(num_generations):
# ---> 25         fitness_scores = [evaluate_strategy(stock_data.copy(), alpha_func,*individual)["Allocated Funds"] for individual in population]
#      26         sorted_population = [x for _, x in sorted(zip(fitness_scores, population), key=lambda pair: pair[0], reverse=True)]
#      27
#
# ~/GA/utils/optimizer.py in <listcomp>(.0)
#      23
#      24     for generation in range(num_generations):
# ---> 25         fitness_scores = [evaluate_strategy(stock_data.copy(), alpha_func,*individual)["Allocated Funds"] for individual in population]
#      26         sorted_population = [x for _, x in sorted(zip(fitness_scores, population), key=lambda pair: pair[0], reverse=True)]
#      27
#
# /tmp/ipykernel_3727/814579808.py in evaluate_strategy(data, alpha_func, *args)
#      92             "Win Rate": win_rate,
#      93             "Allocated Funds": allocated_funds,
# ---> 94             "Sharpe Ratio": calculate_sortino_ratio(pd.Series(returns))
#      95         }
#      96
#
# ~/GA/utils/data_utils.py in calculate_sortino_ratio(returns, risk_free_rate)
#      25
#      26 def calculate_sortino_ratio(returns, risk_free_rate=0):
# ---> 27     downside_returns = np.minimum(returns - risk_free_rate, 0)
#      28     downside_deviation = np.std(downside_returns, ddof=1)
#      29
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py in __sub__(self, other)
#     192     @unpack_zerodim_and_defer("__sub__")
#     193     def __sub__(self, other):
# --> 194         return self._arith_method(other, operator.sub)
#     195
#     196     @unpack_zerodim_and_defer("__rsub__")
#
# ~/.local/lib/python3.10/site-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5813     def _arith_method(self, other, op):
#    5814         self, other = self._align_for_op(other)
# -> 5815         return base.IndexOpsMixin._arith_method(self, other, op)
#    5816
#    5817     def _align_for_op(self, right, align_asobject: bool = False):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1369
#    1370     def _arith_method(self, other, op):
# -> 1371         res_name = ops.get_op_result_name(self, other)
#    1372
#    1373         lvalues = self._values
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in get_op_result_name(left, right)
#      94         Usually a string
#      95     """
# ---> 96     if isinstance(right, (ABCSeries, ABCIndex)):
#      97         name = _maybe_match_name(left, right)
#      98     else:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/generic.py in _instancecheck(cls, inst)
#      42     @classmethod  # type: ignore[misc]
#      43     def _instancecheck(cls, inst) -> bool:
# ---> 44         return _check(inst) and not isinstance(inst, type)
#      45
#      46     @classmethod  # type: ignore[misc]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/generic.py in _check(inst)
#      35 # objects
#      36 def create_pandas_abc_type(name, attr, comp):
# ---> 37     def _check(inst) -> bool:
#      38         return getattr(inst, attr, "_typ") in comp
#      39
#
# KeyboardInterrupt:

# %%
data= yf.download("LT.NS", start = '2023-08-01',end='2024-02-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
evaluate_strategy(data,alpha11,17, 5, 0, -0.9838885246829239)

# %%
signal.hist()

# %%
pd.Series([1,2,3])<0

# %%
data = stock_data

# %%
pd.Series(signal).hist()

# %%
a =generate_individual(alpha14)

# %%
list(a.values())

# %%
def example_function(param1, *args, param2="default", **kwargs):
    print("param1:", param1)
    print("param2:", param2)
    print("Additional positional arguments:", *args[:-2])
    print("Additional keyword arguments:", kwargs)

# %%
example_function(1,2,3,4,5,5,6,7)
